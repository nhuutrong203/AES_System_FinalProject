# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/processing/task2_ielts_dataset.csv')

print("Dataset shape:", df.shape)

df.head()
# Out:
# Dataset shape: (9782, 10)
#                                             Question  \
# 0  Many people assume that the goal of every coun...
# 1  Some people believe that giving longer prison ...
# 2  Some people believe that preserving natural en...
# 3  Some people believe that homework should not b...
# 4  Some people believe that governments should pa...
#
#                                                Essay  Task_Response  \
# 0  More materials and goods are produced by a cou...            NaN
# 1  There is an opinion which is that the longer p...            NaN
# 2  Some people believe that preserving natural en...            NaN
# 3  The benefits of giving or not giving homework ...            NaN
# 4  This essay agrees on the need of that governme...            NaN
#
#    Coherence_Cohesion  Lexical_Resource  Range_Accuracy  Overall  \
# 0                 NaN               NaN             NaN      6.5
# 1                 NaN               NaN             NaN      6.0
# 2                 NaN               NaN             NaN      8.0
# 3                 NaN               NaN             NaN      9.0
# 4                 NaN               NaN             NaN      5.5
#
#    Overall_Clean Examiner_Comment  length
# 0            6.5              NaN     435
# 1            6.0              NaN     295
# 2            8.0              NaN     371
# 3            9.0              NaN     309
# 4            5.5              NaN     311

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9782 entries, 0 to 9781
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Question            9782 non-null   object
#  1   Essay               9782 non-null   object
#  2   Task_Response       9120 non-null   float64
#  3   Coherence_Cohesion  9120 non-null   float64
#  4   Lexical_Resource    9120 non-null   float64
#  5   Range_Accuracy      9120 non-null   float64
#  6   Overall             9782 non-null   float64
#  7   Overall_Clean       9782 non-null   float64
#  8   Examiner_Comment    9133 non-null   object
#  9   length              9782 non-null   int64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 764.3+ KB

# %%
df.head(10)
# Out:
#                                             Question  \
# 0  Many people assume that the goal of every coun...
# 1  Some people believe that giving longer prison ...
# 2  Some people believe that preserving natural en...
# 3  Some people believe that homework should not b...
# 4  Some people believe that governments should pa...
# 5  Some people believe that governments should pa...
# 6  Some people believe that governments should pa...
# 7  Some people believe that governments should pa...
# 8  Some people believe that governments should pa...
# 9  Some people believe that governments should pa...
#
#                                                Essay  Task_Response  \
# 0  More materials and goods are produced by a cou...            NaN
# 1  There is an opinion which is that the longer p...            NaN
# 2  Some people believe that preserving natural en...            NaN
# 3  The benefits of giving or not giving homework ...            NaN
# 4  This essay agrees on the need of that governme...            NaN
# 5  Regarding the suggestions that governments sho...            NaN
# 6  Nowadays many people argue that univerties gra...            NaN
# 7  It is believed that governments ought to pay f...            NaN
# 8  In recent years, in some countries, including ...            NaN
# 9  Going to university is an important step in li...            NaN
#
#    Coherence_Cohesion  Lexical_Resource  Range_Accuracy  Overall  \
# 0                 NaN               NaN             NaN      6.5
# 1                 NaN               NaN             NaN      6.0
# 2                 NaN               NaN             NaN      8.0
# 3                 NaN               NaN             NaN      9.0
# 4                 NaN               NaN             NaN      5.5
# 5                 NaN               NaN             NaN      6.0
# 6                 NaN               NaN             NaN      5.5
# 7                 NaN               NaN             NaN      6.5
# 8                 NaN               NaN             NaN      5.5
# 9                 NaN               NaN             NaN      7.5
#
#    Overall_Clean Examiner_Comment  length
# 0            6.5              NaN     435
# 1            6.0              NaN     295
# 2            8.0              NaN     371
# 3            9.0              NaN     309
# 4            5.5              NaN     311
# 5            6.0              NaN     267
# 6            5.5              NaN     265
# 7            6.5              NaN     258
# 8            5.5              NaN     339
# 9            7.5              NaN     409

# %%
df.tail(10)
# Out:
#                                                Question  \
# 9772  Some people claim that many things that childr...
# 9773  Some people think that secondary school childr...
# 9774  Some people believe that children at school sh...
# 9775  Some people think that art is an essential sub...
# 9776  Some people think that art is an essential sub...
# 9777  Some people think that art is an essential sub...
# 9778  Some people think that art is an essential sub...
# 9779  Some people think that art is essential subjec...
# 9780  Some people think that art is an essential sub...
# 9781  “Some people say that the education system is ...
#
#                                                   Essay  Task_Response  \
# 9772  It is argued that some of the lessons that are...            8.0
# 9773  The knowledge of various sections is significa...            8.5
# 9774  Fine art is found by many people. It is argued...            7.0
# 9775  There has been a heated discussion around art ...            5.5
# 9776  A highly controversial issue today relates to ...            6.0
# 9777  craft is Known as better formal to explain fee...            6.0
# 9778  Art is Known as better formal to explain felli...            4.0
# 9779  Art is an integral part of our lives. Art help...            6.0
# 9780  Everything we encounter in this world take sha...            6.0
# 9781  Education plays a vital role in the developmen...            6.0
#
#       Coherence_Cohesion  Lexical_Resource  Range_Accuracy  Overall  \
# 9772                 7.0               7.0             7.0      8.0
# 9773                 8.5               8.0             8.0      8.5
# 9774                 7.0               7.0             7.0      7.0
# 9775                 5.0               6.0             5.5      6.5
# 9776                 5.5               5.5             5.0      5.5
# 9777                 6.0               5.5             5.0      6.0
# 9778                 3.5               3.5             4.0      4.5
# 9779                 6.0               6.0             6.0      6.0
# 9780                 6.0               6.0             6.0      6.0
# 9781                 6.0               6.0             6.0      6.0
#
#       Overall_Clean                                   Examiner_Comment  length
# 9772            7.5  ## Task Achievement:\n- The candidate has clea...     298
# 9773            8.5  ## Task Achievement:\n- The candidate has addr...     328
# 9774            7.0  ## Task Achievement:\n- The essay addresses th...     322
# 9775            5.5  ## Task Achievement:\n- The candidate has effe...     279
# 9776            5.5  **Task Achievement:**\n\n- The essay addresses...     298
# 9777            5.5  ## Task Achievement:\nThe candidate has addres...     368
# 9778            4.0  ## Task Achievement:\n- The candidate has addr...     364
# 9779            6.0  ### Task Achievement:\n- The candidate has par...     255
# 9780            6.0  ### Task Achievement:\n\n- The essay addresses...     338
# 9781            6.0  This essay needs some work. It has a good stru...     239

# %%
print("Missing values:\n")
print(df.isnull().sum())

print("\nOverall missing:", df["Overall_Clean"].isnull().sum())
# Out:
# Missing values:
#
# Question                0
# Essay                   0
# Task_Response         662
# Coherence_Cohesion    662
# Lexical_Resource      662
# Range_Accuracy        662
# Overall                 0
# Overall_Clean           0
# Examiner_Comment      649
# length                  0
# dtype: int64
#
# Overall missing: 0

# %%
df.nunique()
# Out:
# Question              3785
# Essay                 9782
# Task_Response           19
# Coherence_Cohesion      19
# Lexical_Resource        18
# Range_Accuracy          18
# Overall                 30
# Overall_Clean           19
# Examiner_Comment      9133
# length                 446
# dtype: int64

# %%
duplicate_essay = df["Essay"].duplicated().sum()
print("Duplicate essays:", duplicate_essay)
# Out:
# Duplicate essays: 0

# %%
essay_multi_question = (
    df.groupby("Essay")["Question"]
    .nunique()
    .value_counts()
)

print("Essay -> number of unique Questions:\n")
print(essay_multi_question)
# Out:
# Essay -> number of unique Questions:
#
# Question
# 1    9782
# Name: count, dtype: int64

# %%
essay_multi_score = (
    df.groupby("Essay")["Overall_Clean"]
    .nunique()
    .value_counts()
)

print("Essay -> number of unique Overall scores:\n")
print(essay_multi_score)
# Out:
# Essay -> number of unique Overall scores:
#
# Overall
# 1    9782
# Name: count, dtype: int64

# %%
print("Unique Overall scores:")
print(sorted(df["Overall_Clean"].unique()))
# Out:
# Unique Overall scores:
# [np.float64(0.0), np.float64(0.25), np.float64(1.0), np.float64(1.25), np.float64(1.5), np.float64(2.0), np.float64(2.5), np.float64(3.0), np.float64(3.25), np.float64(3.5), np.float64(3.75), np.float64(4.0), np.float64(4.25), np.float64(4.5), np.float64(4.75), np.float64(5.0), np.float64(5.25), np.float64(5.5), np.float64(5.75), np.float64(6.0), np.float64(6.25), np.float64(6.5), np.float64(6.75), np.float64(7.0), np.float64(7.25), np.float64(7.5), np.float64(7.75), np.float64(8.0), np.float64(8.5), np.float64(9.0)]

# %% [markdown]
# Raw dataset may contain missing values in criteria columns,
# which will be handled during preprocessing.

# %%
bins = np.arange(1, 9.5, 0.5)

hist = plt.hist(
    df["Overall_Clean"],
    bins=bins,
    edgecolor='black',
    alpha=0.7
)

plt.title("Distribution of IELTS Scores")
plt.xlabel("IELTS Scores")
plt.ylabel("Frequency")

heights = hist[0]
edges = hist[1]

for i in range(len(heights)):
    x = (edges[i] + edges[i+1]) / 2
    y = heights[i]

    if y > 0:
        plt.text(x, y, str(int(y)), ha='center', va='bottom')

plt.xticks(np.arange(1, 9.5, 0.5))

plt.show()

# %%
score_counts = df["Overall_Clean"].value_counts().sort_index()

score_counts

score_counts.plot(kind="bar")

plt.title("Score Class Distribution")
plt.xlabel("Band Score")
plt.ylabel("Number of Essays")

plt.show()


# This analysis identifies whether the dataset suffers from class imbalance.

# %%
print("Skewness:", df["Overall_Clean"].skew())
print("Kurtosis:", df["Overall_Clean"].kurtosis())
# Out:
# Skewness: -0.7289463703040462
# Kurtosis: 0.5530871049298587

# %%
cumulative_freq = (
    df
    .groupby("Overall_Clean")
    .agg(Count=("Overall_Clean", "count"))
    .sort_index()
)

cumulative_freq["Cumulative_Frequency"] = cumulative_freq["Count"].cumsum()

total_count = cumulative_freq["Count"].sum()

cumulative_freq["Percentage"] = round(
    (cumulative_freq["Cumulative_Frequency"] / total_count) * 100,
    3
)

cumulative_freq
# Out:
#          Count  Cumulative_Frequency  Percentage
# Overall
# 0.00         8                     8       0.082
# 0.25         1                     9       0.092
# 1.00        29                    38       0.388
# 1.25         2                    40       0.409
# 1.50         7                    47       0.480
# 2.00        91                   138       1.411
# 2.50        66                   204       2.085
# 3.00       150                   354       3.619
# 3.25         7                   361       3.690
# 3.50       164                   525       5.367
# 3.75         9                   534       5.459
# 4.00       750                  1284      13.126
# 4.25         9                  1293      13.218
# 4.50       475                  1768      18.074
# 4.75        10                  1778      18.176
# 5.00       490                  2268      23.185
# 5.25        30                  2298      23.492
# 5.50       767                  3065      31.333
# 5.75        39                  3104      31.732
# 6.00      1445                  4549      46.504
# 6.25        74                  4623      47.260
# 6.50      1571                  6194      63.320
# 6.75        70                  6264      64.036
# 7.00      1470                  7734      79.064
# 7.25        55                  7789      79.626
# 7.50       998                  8787      89.828
# 7.75        16                  8803      89.992
# 8.00       566                  9369      95.778
# 8.50       345                  9714      99.305
# 9.00        68                  9782     100.000

# %%
plt.figure(figsize=(10,6))

plt.plot(
    cumulative_freq.index,
    cumulative_freq["Percentage"],
    marker='o'
)

plt.title("Cumulative Percentage of IELTS Scores")
plt.xlabel("Band Score")
plt.ylabel("Percentage (%)")

plt.xticks(np.arange(1, 9.5, 0.5))

plt.grid()

plt.show()

# %%
df["length"] = df["Essay"].str.split().str.len()

df["length"].describe()
# Out:
# count    9782.000000
# mean      294.592312
# std        58.398059
# min         1.000000
# 25%       264.000000
# 50%       290.000000
# 75%       323.000000
# max      1557.000000
# Name: length, dtype: float64

# %%
plt.hist(
    df["length"],
    bins=50,
    edgecolor="black"
)

plt.title("Essay Length Distribution")
plt.xlabel("Word Count")
plt.ylabel("Frequency")

plt.show()

# %%
length_by_score = (
    df
    .groupby("Overall_Clean")
    .agg(mean_length=("length","mean"))
    .reset_index()
)

length_by_score
# Out:
#     Overall  mean_length
# 0      0.00   189.125000
# 1      0.25   169.000000
# 2      1.00   228.206897
# 3      1.25   290.000000
# 4      1.50   289.714286
# 5      2.00   236.835165
# 6      2.50   216.969697
# 7      3.00   232.300000
# 8      3.25   207.142857
# 9      3.50   270.335366
# 10     3.75   231.444444
# 11     4.00   238.037333
# 12     4.25   289.222222
# 13     4.50   296.347368
# 14     4.75   287.800000
# 15     5.00   296.706122
# 16     5.25   274.133333
# 17     5.50   296.419817
# 18     5.75   289.102564
# 19     6.00   300.307958
# 20     6.25   295.905405
# 21     6.50   301.672183
# 22     6.75   307.485714
# 23     7.00   304.776871
# 24     7.25   299.490909
# 25     7.50   308.119238
# 26     7.75   308.875000
# 27     8.00   316.897527
# 28     8.50   309.200000
# 29     9.00   307.735294

# %%
plt.plot(
    length_by_score["Overall"],
    length_by_score["mean_length"],
    marker='o'
)

plt.title("Average Essay Length by Band Score")
plt.xlabel("Band Score")
plt.ylabel("Average Word Count")

plt.grid()

plt.show()

# %%
plt.figure(figsize=(10,6))

plt.scatter(
    df["Overall_Clean"],
    df["length"],
    alpha=0.5
)

a, b = np.polyfit(df["Overall_Clean"], df["length"], 1)

x_line = np.linspace(
    df["Overall_Clean"].min(),
    df["Overall_Clean"].max(),
    100
)

y_line = a * x_line + b

plt.plot(
    x_line,
    y_line,
    color='red',
    label=f'y = {a:.2f}x + {b:.2f}'
)

plt.title("Essay Length vs Overall Score")
plt.xlabel("Overall Score")
plt.ylabel("Essay Length")

plt.xticks(np.arange(1, 9.5, 0.5))

plt.grid()
plt.legend()

plt.show()

# %%
score_variance = (
    df
    .groupby("Overall_Clean")
    .agg(
        mean_length=("length","mean"),
        std_length=("length","std"),
        count=("length","count")
    )
)

score_variance
# Out:
#          mean_length  std_length  count
# Overall
# 0.00      189.125000   83.235359      8
# 0.25      169.000000         NaN      1
# 1.00      228.206897   90.717135     29
# 1.25      290.000000   15.556349      2
# 1.50      289.714286  148.424744      7
# 2.00      236.835165   99.294205     91
# 2.50      216.969697   85.440572     66
# 3.00      232.300000   78.618760    150
# 3.25      207.142857   84.796676      7
# 3.50      270.335366   62.006261    164
# 3.75      231.444444   82.861498      9
# 4.00      238.037333   77.328586    750
# 4.25      289.222222   50.753763      9
# 4.50      296.347368   82.143536    475
# 4.75      287.800000   67.041944     10
# 5.00      296.706122   51.981271    490
# 5.25      274.133333   59.322458     30
# 5.50      296.419817   45.477088    767
# 5.75      289.102564   38.704545     39
# 6.00      300.307958   49.265140   1445
# 6.25      295.905405   49.367276     74
# 6.50      301.672183   44.577551   1571
# 6.75      307.485714   46.784038     70
# 7.00      304.776871   44.218783   1470
# 7.25      299.490909   39.201697     55
# 7.50      308.119238   47.402022    998
# 7.75      308.875000   52.264551     16
# 8.00      316.897527   48.572837    566
# 8.50      309.200000   39.829623    345
# 9.00      307.735294   38.695758     68

# %%
score_variance = (
    df
    .groupby("Overall_Clean")
    .agg(
        mean_length=("length","mean"),
        std_length=("length","std"),
        count=("length","count")
    )
)

score_variance
# Out:
#          mean_length  std_length  count
# Overall
# 0.00      189.125000   83.235359      8
# 0.25      169.000000         NaN      1
# 1.00      228.206897   90.717135     29
# 1.25      290.000000   15.556349      2
# 1.50      289.714286  148.424744      7
# 2.00      236.835165   99.294205     91
# 2.50      216.969697   85.440572     66
# 3.00      232.300000   78.618760    150
# 3.25      207.142857   84.796676      7
# 3.50      270.335366   62.006261    164
# 3.75      231.444444   82.861498      9
# 4.00      238.037333   77.328586    750
# 4.25      289.222222   50.753763      9
# 4.50      296.347368   82.143536    475
# 4.75      287.800000   67.041944     10
# 5.00      296.706122   51.981271    490
# 5.25      274.133333   59.322458     30
# 5.50      296.419817   45.477088    767
# 5.75      289.102564   38.704545     39
# 6.00      300.307958   49.265140   1445
# 6.25      295.905405   49.367276     74
# 6.50      301.672183   44.577551   1571
# 6.75      307.485714   46.784038     70
# 7.00      304.776871   44.218783   1470
# 7.25      299.490909   39.201697     55
# 7.50      308.119238   47.402022    998
# 7.75      308.875000   52.264551     16
# 8.00      316.897527   48.572837    566
# 8.50      309.200000   39.829623    345
# 9.00      307.735294   38.695758     68

# %%
plt.errorbar(
    score_variance.index,
    score_variance["mean_length"],
    yerr=score_variance["std_length"],
    fmt='o'
)

plt.title("Score Variance Analysis")
plt.xlabel("Band Score")
plt.ylabel("Essay Length (Mean ± Std)")

plt.grid()
plt.show()
# This analysis helps understand the variance of essays by score.

# %%
print("Very short essays:")
df[df["length"] < 100][["Essay","Overall_Clean"]].head()

print("\nVery long essays:")
df[df["length"] > 300][["Essay","Overall_Clean"]].head()
# Out:
# Very short essays:
#
# Very long essays:
#                                                Essay  Overall
# 0  More materials and goods are produced by a cou...      6.5
# 2  Some people believe that preserving natural en...      8.0
# 3  The benefits of giving or not giving homework ...      9.0
# 4  This essay agrees on the need of that governme...      5.5
# 8  In recent years, in some countries, including ...      5.5

# %%
criteria = [
    "Task_Response",
    "Coherence_Cohesion",
    "Lexical_Resource",
    "Range_Accuracy"
]

# %%
for col in criteria:
    plt.hist(df[col], bins=np.arange(1,9.5,0.5), edgecolor="black")
    plt.title(f"{col} Distribution")
    plt.xlabel("Score")
    plt.ylabel("Frequency")
    plt.show()

# %%
corr = df[criteria + ["Overall_Clean"]].corr()

corr
# Out:
#                     Task_Response  Coherence_Cohesion  Lexical_Resource  \
# Task_Response            1.000000            0.966297          0.961124
# Coherence_Cohesion       0.966297            1.000000          0.959952
# Lexical_Resource         0.961124            0.959952          1.000000
# Range_Accuracy           0.955011            0.964275          0.977978
# Overall                  0.929313            0.903706          0.908641
#
#                     Range_Accuracy   Overall
# Task_Response             0.955011  0.929313
# Coherence_Cohesion        0.964275  0.903706
# Lexical_Resource          0.977978  0.908641
# Range_Accuracy            1.000000  0.903472
# Overall                   0.903472  1.000000

# %%
plt.imshow(corr, cmap='coolwarm', interpolation='none')
plt.colorbar()

plt.xticks(range(len(corr.columns)), corr.columns, rotation=45)
plt.yticks(range(len(corr.columns)), corr.columns)

for i in range(len(corr.columns)):
    for j in range(len(corr.columns)):
        plt.text(
            j, i,
            f"{corr.iloc[i, j]:.2f}",
            ha='center', va='center',
            color='black'
        )

plt.title("Correlation Matrix")
plt.show()

# %%
def round_band(x):
    if pd.isna(x):
        return np.nan

    integer = int(x)
    decimal = x - integer

    if decimal < 0.25:
        return integer
    elif decimal <= 0.5:
        return integer + 0.5
    elif decimal < 0.75:
        return integer + 0.5
    else:
        return integer + 1

# %%
df["criteria_mean"] = df[criteria].mean(axis=1).apply(round_band)

diff = (df["criteria_mean"] - df["Overall_Clean"]).abs()

print("Mean difference:", diff.mean())
print("Max difference:", diff.max())
# Out:
# Mean difference: 0.3419407894736842
# Max difference: 6.0

# %%
plt.hist(diff, bins=50, edgecolor="black")

plt.title("Difference between Mean Criteria and Overall")
plt.xlabel("Absolute Difference")
plt.ylabel("Frequency")

plt.show()

# %%
print("Number of unique questions:", df["Question"].nunique())
# Out:
# Number of unique questions: 3785

# %%
question_counts = df["Question"].value_counts()

question_counts.head()
# Out:
# Question
# Some people believe that teenagers should be required to do unpaid community work in their free time. This can benefit teenagers and the community as well. To what extent do you agree or disagree?                         158
# In some countries, more and more people are becoming interested in finding out about the history of the house or building they live in. What are the reasons for this? How can people research this?                          93
# Some people think that instead of preventing climate change, we need to find a way to live with it. To what extent do you agree or disagree?                                                                                  71
# Some people believe that studying at university or college is the best route to a successful career, while others believe that it is better to get a job straight after school. Discuss both views and give your opinion.     63
# The increase in the production of consumer goods results in damage to the natural environment. What are the causes of this? What can be done to solve this problem?                                                           62
# Name: count, dtype: int64

# %%
question_counts.plot(kind="hist", bins=50)

plt.title("Number of Essays per Question")
plt.xlabel("Count")
plt.ylabel("Frequency")

plt.show()
